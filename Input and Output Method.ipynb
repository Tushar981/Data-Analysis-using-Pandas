# %%
import pandas as pd

# %% [markdown]
# # Pass a URL to the pd.read_csv Method

# %%
url="https://data.cityofnewyork.us/resource/25th-nujf.csv"
baby_name=pd.read_csv(url)

# %%
baby_name.head()
# Out:
#    brth_yr    gndr                      ethcty      nm  cnt  rnk
# 0     2019  FEMALE  ASIAN AND PACIFIC ISLANDER   Chloe  131    1
# 1     2019  FEMALE  ASIAN AND PACIFIC ISLANDER  Olivia  109    2
# 2     2019  FEMALE  ASIAN AND PACIFIC ISLANDER     Mia   88    3
# 3     2019  FEMALE  ASIAN AND PACIFIC ISLANDER  Sophia   71    4
# 4     2019  FEMALE  ASIAN AND PACIFIC ISLANDER    Emma   71    4

# %%
baby_name["nm"]
baby_name["nm"].to_frame()
# Out:
#            nm
# 0       Chloe
# 1      Olivia
# 2         Mia
# 3      Sophia
# 4        Emma
# ..        ...
# 995    Andrew
# 996   Ibrahim
# 997      Adam
# 998  Abdullah
# 999       Ian
#
# [1000 rows x 1 columns]

# %%
baby_name["nm"].to_list()
# Out:
# ['Chloe',
#  'Olivia',
#  'Mia',
#  'Sophia',
#  'Emma',
#  'Amelia',
#  'Charlotte',
#  'Emily',
#  'Grace',
#  'Isabella',
#  'Ella',
#  'Evelyn',
#  'Ava',
#  'Hannah',
#  'Bella',
#  'Aria',
#  'Sarah',
#  'Hailey',
#  'Arya',
#  'Claire',
#  'Fatima',
#  'Ellie',
#  'Maryam',
#  'Kayla',
#  'Zoe',
#  'Audrey',
#  'Avery',
#  'Abigail',
#  'Anna',
#  'Maya',
#  'Alyssa',
#  'Alice',
#  'Sofia',
#  'Riley',
#  'Jasmine',
#  'Zoey',
#  'Celine',
#  'Emilia',
#  'Tenzin',
#  'Inaaya',
#  'Joanna',
#  'Fiona',
#  'Alina',
#  'Sophie',
#  'Leah',
#  'Anaya',
#  'Ayesha',
#  'Luna',
#  'Zainab',
#  'Eva',
#  'Annie',
#  'Amaya',
#  'Mila',
#  'Angela',
#  'Elena',
#  'Inaya',
#  'Anabia',
#  'Ariana',
#  'Manha',
#  'Penelope',
#  'Zara',
#  'Nina',
#  'Katherine',
#  'Aliza',
#  'Scarlett',
#  'Zahra',
#  'Layla',
#  'Natalie',
#  'Eleanor',
#  'Harper',
#  'Jannatul',
#  'Irene',
#  'Kylie',
#  'Aiza',
#  'Eliana',
#  'Phoebe',
#  'Jocelyn',
#  'Sara',
#  'Ashley',
#  'Cynthia',
# ...

# %%
baby_name["nm"].to_dict()
# Out:
# {0: 'Chloe',
#  1: 'Olivia',
#  2: 'Mia',
#  3: 'Sophia',
#  4: 'Emma',
#  5: 'Amelia',
#  6: 'Charlotte',
#  7: 'Emily',
#  8: 'Grace',
#  9: 'Isabella',
#  10: 'Ella',
#  11: 'Evelyn',
#  12: 'Ava',
#  13: 'Hannah',
#  14: 'Bella',
#  15: 'Aria',
#  16: 'Sarah',
#  17: 'Hailey',
#  18: 'Arya',
#  19: 'Claire',
#  20: 'Fatima',
#  21: 'Ellie',
#  22: 'Maryam',
#  23: 'Kayla',
#  24: 'Zoe',
#  25: 'Audrey',
#  26: 'Avery',
#  27: 'Abigail',
#  28: 'Anna',
#  29: 'Maya',
#  30: 'Alyssa',
#  31: 'Alice',
#  32: 'Sofia',
#  33: 'Riley',
#  34: 'Jasmine',
#  35: 'Zoey',
#  36: 'Celine',
#  37: 'Emilia',
#  38: 'Tenzin',
#  39: 'Inaaya',
#  40: 'Joanna',
#  41: 'Fiona',
#  42: 'Alina',
#  43: 'Sophie',
#  44: 'Leah',
#  45: 'Anaya',
#  46: 'Ayesha',
#  47: 'Luna',
#  48: 'Zainab',
#  49: 'Eva',
#  50: 'Annie',
#  51: 'Amaya',
#  52: 'Mila',
#  53: 'Angela',
#  54: 'Elena',
#  55: 'Inaya',
#  56: 'Anabia',
#  57: 'Ariana',
#  58: 'Manha',
#  59: 'Penelope',
#  60: 'Zara',
#  61: 'Nina',
# ...

# %%
",".join(baby_name["nm"].str.title())
# Out:
# 'Chloe,Olivia,Mia,Sophia,Emma,Amelia,Charlotte,Emily,Grace,Isabella,Ella,Evelyn,Ava,Hannah,Bella,Aria,Sarah,Hailey,Arya,Claire,Fatima,Ellie,Maryam,Kayla,Zoe,Audrey,Avery,Abigail,Anna,Maya,Alyssa,Alice,Sofia,Riley,Jasmine,Zoey,Celine,Emilia,Tenzin,Inaaya,Joanna,Fiona,Alina,Sophie,Leah,Anaya,Ayesha,Luna,Zainab,Eva,Annie,Amaya,Mila,Angela,Elena,Inaya,Anabia,Ariana,Manha,Penelope,Zara,Nina,Katherine,Aliza,Scarlett,Zahra,Layla,Natalie,Eleanor,Harper,Jannatul,Irene,Kylie,Aiza,Eliana,Phoebe,Jocelyn,Sara,Ashley,Cynthia,Ariel,Jessica,Ayat,Vivian,Madeline,Angelina,Melody,Amy,Khadija,Rachel,Stella,Madison,Catherine,Abby,Julia,Nora,Michelle,Aurora,Elise,Elizabeth,Kaylee,Aleena,Ivy,Ada,Naomi,Ariella,Athena,Allison,Alexandra,Mariam,Karen,Cecilia,Iris,Isla,Daisy,Joy,Kiara,Zoya,Ophelia,Erin,Lily,Elina,Miya,Aaliyah,Kelly,Stephanie,Violet,Esther,Alisha,Ruby,Angie,Norah,Rhea,Skylar,Kira,Aliya,Ayra,Aisha,Serena,Selina,Hazel,Hoorain,Muntaha,Vanessa,Vicky,Josephine,Helen,Dua,Madeleine,Nabiha,Jannat,Amara,
# ...

# %%
",".join(baby_name["nm"].str.title().drop_duplicates())
# Out:
# 'Chloe,Olivia,Mia,Sophia,Emma,Amelia,Charlotte,Emily,Grace,Isabella,Ella,Evelyn,Ava,Hannah,Bella,Aria,Sarah,Hailey,Arya,Claire,Fatima,Ellie,Maryam,Kayla,Zoe,Audrey,Avery,Abigail,Anna,Maya,Alyssa,Alice,Sofia,Riley,Jasmine,Zoey,Celine,Emilia,Tenzin,Inaaya,Joanna,Fiona,Alina,Sophie,Leah,Anaya,Ayesha,Luna,Zainab,Eva,Annie,Amaya,Mila,Angela,Elena,Inaya,Anabia,Ariana,Manha,Penelope,Zara,Nina,Katherine,Aliza,Scarlett,Zahra,Layla,Natalie,Eleanor,Harper,Jannatul,Irene,Kylie,Aiza,Eliana,Phoebe,Jocelyn,Sara,Ashley,Cynthia,Ariel,Jessica,Ayat,Vivian,Madeline,Angelina,Melody,Amy,Khadija,Rachel,Stella,Madison,Catherine,Abby,Julia,Nora,Michelle,Aurora,Elise,Elizabeth,Kaylee,Aleena,Ivy,Ada,Naomi,Ariella,Athena,Allison,Alexandra,Mariam,Karen,Cecilia,Iris,Isla,Daisy,Joy,Kiara,Zoya,Ophelia,Erin,Lily,Elina,Miya,Aaliyah,Kelly,Stephanie,Violet,Esther,Alisha,Ruby,Angie,Norah,Rhea,Skylar,Kira,Aliya,Ayra,Aisha,Serena,Selina,Hazel,Hoorain,Muntaha,Vanessa,Vicky,Josephine,Helen,Dua,Madeleine,Nabiha,Jannat,Amara,
# ...

# %%
",".join(baby_name["nm"].str.title().drop_duplicates().sort_values())
# Out:
# 'Aaliyah,Aaron,Abby,Abdullah,Abigail,Ada,Adam,Addison,Adelaide,Adele,Adeline,Adelynn,Adina,Adriana,Ahuva,Aicha,Aiden,Ailani,Aileen,Aisha,Aiza,Alahia,Alaia,Alana,Alani,Alanna,Alayna,Aleah,Aleena,Alessandra,Alessia,Alexa,Alexander,Alexandra,Alexis,Alia,Alice,Alicia,Alina,Alisha,Alison,Aliya,Aliyah,Aliza,Allison,Alma,Alondra,Alyssa,Amaia,Amalia,Amanda,Amani,Amara,Amaya,Amayah,Amber,Amelia,Amelie,Amina,Aminata,Amira,Amirah,Amiyah,Amora,Amy,Ana,Anabia,Analia,Anastasia,Anaya,Andrea,Andrew,Angela,Angelica,Angelina,Angie,Aniyah,Anna,Annabel,Annabelle,Annalise,Annie,Antonella,Anya,April,Arham,Aria,Ariah,Ariana,Arianna,Ariel,Ariella,Arielle,Ariyah,Arlette,Arya,Ashley,Astrid,Athena,Aubree,Aubrey,Audrey,Aurelia,Aurora,Austin,Autumn,Ava,Avery,Aviva,Aya,Ayaan,Ayala,Ayat,Ayesha,Ayla,Ayra,Baila,Batsheva,Beatrice,Bella,Bianca,Bina,Bintou,Blair,Blake,Blima,Blimy,Bracha,Breindy,Briana,Brianna,Brielle,Brooke,Brooklyn,Bruchy,Cali,Camila,Camilla,Camille,Caroline,Cataleya,Catalina,Catherine,Cecilia,Celeste
# ...

# %%
# so as we know that we created some result using the python so if i want to store that data in csv format 
# in that case i need to use to_csv method
# encode=utf-8 mean is if some charcter which are not able to convert into A-z so so this is the standard way with the help 
# we can use it
baby_name.to_csv("NYC_babyName.csv",index=False,columns=["gndr","nm","ethcty"],encoding="utf-8")

# %% [markdown]
# # For Next section we need to install other liabrary
# # conda install xlrd openpyxl

# %%
# The reason behind to install these liabrary so that we can use the excel file 
# and one more interesting thing is if we are going to use excel in that case we will be having multiple number of tabs
import pandas as pd
df=pd.read_excel("Data - Single Worksheet.xlsx")
df.head()
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
# we can access the two way 
# First using the index -> in all the scenrio the 0 will indicate the 1 sheet
# another using the sheet name -> in our case data 1 ,data 2 are the sheet name
pd.read_excel("Data - Multiple Worksheets.xlsx",sheet_name="Data 2")
pd.read_excel("Data - Multiple Worksheets.xlsx",sheet_name=1)
# Out:
#   First Name Last Name           City Gender
# 0     Parker     Power        Raleigh      F
# 1    Preston  Prescott   Philadelphia      F
# 2    Ronaldo   Donaldo         Bangor      M
# 3      Megan   Stiller  San Francisco      M
# 4     Bustin    Jieber         Austin      F

# %%
data1=pd.read_excel("Data - Multiple Worksheets.xlsx",sheet_name=[0,1])

# %%
data2=pd.read_excel("Data - Multiple Worksheets.xlsx",sheet_name=["Data 1","Data 2"])

# %%
# the difference in both top upper result the index got changed 
data1[0] # this way we can access the df
data2["Data 1"] 

# best approach is second one
# Out:
#   First Name Last Name           City Gender
# 0    Brandon     James          Miami      M
# 1       Sean   Hawkins         Denver      M
# 2       Judy       Day    Los Angeles      F
# 3     Ashley      Ruiz  San Francisco      F
# 4  Stephanie     Gomez       Portland      F

# %%
# if we have multiple number of sheets in that case we need to use None this will help
# us to incluse all the sheet
data =pd.read_excel("Data - Multiple Worksheets.xlsx",sheet_name=None)

# %%
data
# Out:
# {'Data 1':   First Name Last Name           City Gender
#  0    Brandon     James          Miami      M
#  1       Sean   Hawkins         Denver      M
#  2       Judy       Day    Los Angeles      F
#  3     Ashley      Ruiz  San Francisco      F
#  4  Stephanie     Gomez       Portland      F,
#  'Data 2':   First Name Last Name           City Gender
#  0     Parker     Power        Raleigh      F
#  1    Preston  Prescott   Philadelphia      F
#  2    Ronaldo   Donaldo         Bangor      M
#  3      Megan   Stiller  San Francisco      M
#  4     Bustin    Jieber         Austin      F}

# %% [markdown]
# # Export Excel File

# %%
url="https://data.cityofnewyork.us/resource/25th-nujf.csv"
baby_name=pd.read_csv(url)
baby_name.head()
# Out:
#    brth_yr    gndr                      ethcty      nm  cnt  rnk
# 0     2019  FEMALE  ASIAN AND PACIFIC ISLANDER   Chloe  131    1
# 1     2019  FEMALE  ASIAN AND PACIFIC ISLANDER  Olivia  109    2
# 2     2019  FEMALE  ASIAN AND PACIFIC ISLANDER     Mia   88    3
# 3     2019  FEMALE  ASIAN AND PACIFIC ISLANDER  Sophia   71    4
# 4     2019  FEMALE  ASIAN AND PACIFIC ISLANDER    Emma   71    4

# %%
male=baby_name[baby_name["gndr"]=="MALE"]
female=baby_name[baby_name["gndr"]=="FEMALE"]

# %%
female
# Out:
#      brth_yr    gndr                      ethcty        nm  cnt  rnk
# 0       2019  FEMALE  ASIAN AND PACIFIC ISLANDER     Chloe  131    1
# 1       2019  FEMALE  ASIAN AND PACIFIC ISLANDER    Olivia  109    2
# 2       2019  FEMALE  ASIAN AND PACIFIC ISLANDER       Mia   88    3
# 3       2019  FEMALE  ASIAN AND PACIFIC ISLANDER    Sophia   71    4
# 4       2019  FEMALE  ASIAN AND PACIFIC ISLANDER      Emma   71    4
# ..       ...     ...                         ...       ...  ...  ...
# 961     2019  FEMALE          WHITE NON HISPANIC     Reizy   10   84
# 962     2019  FEMALE          WHITE NON HISPANIC    Noelle   10   84
# 963     2019  FEMALE          WHITE NON HISPANIC      Riva   10   84
# 964     2019  FEMALE          WHITE NON HISPANIC     Tessa   10   84
# 965     2019  FEMALE          WHITE NON HISPANIC  Serafina   10   84
#
# [966 rows x 6 columns]

# %%
male
# Out:
#      brth_yr  gndr                      ethcty         nm  cnt  rnk
# 966     2019  MALE  ASIAN AND PACIFIC ISLANDER      Ethan  154    1
# 967     2019  MALE  ASIAN AND PACIFIC ISLANDER      Lucas  153    2
# 968     2019  MALE  ASIAN AND PACIFIC ISLANDER      Aiden  147    3
# 969     2019  MALE  ASIAN AND PACIFIC ISLANDER   Muhammad  143    4
# 970     2019  MALE  ASIAN AND PACIFIC ISLANDER     Jayden  118    5
# 971     2019  MALE  ASIAN AND PACIFIC ISLANDER       Ryan  110    6
# 972     2019  MALE  ASIAN AND PACIFIC ISLANDER     Jasper  107    7
# 973     2019  MALE  ASIAN AND PACIFIC ISLANDER       Liam   80    8
# 974     2019  MALE  ASIAN AND PACIFIC ISLANDER     Daniel   73    9
# 975     2019  MALE  ASIAN AND PACIFIC ISLANDER       Noah   69   10
# 976     2019  MALE  ASIAN AND PACIFIC ISLANDER      Mason   65   11
# 977     2019  MALE  ASIAN AND PACIFIC ISLANDER        Leo   58   12
# 978     2019  MALE  ASIAN AND PACIFIC ISLANDER    William   58   12
# ...

# %%
excel_file=pd.ExcelWriter("Baby_name.xlsx")

# %%
female.to_excel(excel_file,sheet_name="Male",index=False)
male.to_excel(excel_file,sheet_name="Female",index=False)

# %%
excel_file.save()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 excel_file.save()
#
# AttributeError: 'OpenpyxlWriter' object has no attribute 'save'
